# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/processed/bus_delay_simulation.parquet")
df
# Out:
#              trip_id  route_id  stop_id   stop_lat   stop_lon  stop_sequence  \
# 0        10001_08_10     10001     3928  28.703650  77.100518              0
# 1        10001_08_10     10001     3929  28.706167  77.102720              1
# 2        10001_08_10     10001     3930  28.709155  77.105354              2
# 3        10001_08_10     10001    20001  28.706559  77.110366              3
# 4        10001_08_10     10001    20002  28.704488  77.113473              4
# ...              ...       ...      ...        ...        ...            ...
# 3724315      9_09_30         9     2988  28.692750  77.077417             44
# 3724316      9_09_30         9     2989  28.695400  77.073500             45
# 3724317      9_09_30         9     2990  28.700500  77.075300             46
# 3724318      9_09_30         9     2991  28.701600  77.075200             47
# 3724319      9_09_30         9     1164  28.703449  77.075009             48
#
# ...

# %%
df.dtypes
# Out:
# trip_id                      object
# route_id                      int64
# stop_id                       int64
# stop_lat                    float64
# stop_lon                    float64
# stop_sequence                 int64
# normalized_stop_position    float64
# scheduled_arrival_unix        int64
# gps_timestamp                 int64
# hour_of_day                   int64
# day_of_week                   int64
# route_id_freq                 int64
# stop_id_freq                  int64
# trip_id_freq                  int64
# distance_to_prev_stop_km    float64
# prev_delay                  float64
# rolling_delay_3             float64
# delay_minutes               float64
# dtype: object

# %%
df.head(5)
# Out:
#        trip_id  route_id  stop_id   stop_lat   stop_lon  stop_sequence  \
# 0  10001_08_10     10001     3928  28.703650  77.100518              0
# 1  10001_08_10     10001     3929  28.706167  77.102720              1
# 2  10001_08_10     10001     3930  28.709155  77.105354              2
# 3  10001_08_10     10001    20001  28.706559  77.110366              3
# 4  10001_08_10     10001    20002  28.704488  77.113473              4
#
#    normalized_stop_position  scheduled_arrival_unix  gps_timestamp  \
# 0                  0.000000              1742803800     1742804455
# 1                  0.013514              1742803884     1742804496
# 2                  0.027027              1742803985     1742804575
# 3                  0.040541              1742804121     1742804615
# 4                  0.054054              1742804212     1742804833
#
#    hour_of_day  day_of_week  route_id_freq  stop_id_freq  trip_id_freq  \
# ...
